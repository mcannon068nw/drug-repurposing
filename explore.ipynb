# %%
import pandas as pd
import requests
import json
from tqdm import tqdm
# tqdm.pandas()

# %% [markdown]
# ### Functions

# %%
# Normalize a given term and return match types/concept ids
def normalize(term):
    url = f'https://normalize.cancervariants.org/therapy/normalize?q={term}&infer_namespace=true' 

    r = requests.get(url)

    if r.status_code == 200:
        data = r.json()
        try:
            return([term,data['match_type'],data['therapy_descriptor']['therapy_id']])
        except:
            return([term,None, None])

    else:
        return([term,None, None])

# %%
# Check a dataframe cell for a normalization success/failure
def is_normalized(entry):
    if entry == None:
        return('Failure')
    else:
        return('Success')

# %% [markdown]
# ### Data

# %%
# Repurposing Hub
# https://clue.io/repurposing

df = pd.read_csv('data/repurposing_drugs_20200324.txt',sep='\t',header=9)
df
# Out:
#                         pert_iname clinical_phase  \
# 0              (R)-(-)-apomorphine       Launched
# 1                 (R)-(-)-rolipram        Phase 1
# 2                     (R)-baclofen        Phase 3
# 3                 (S)-(+)-rolipram        Phase 1
# 4     [sar9,met(o2)11]-substance-p    Preclinical
# ...                            ...            ...
# 6793                      8-M-PDOT    Preclinical
# 6794                    80841-78-7    Preclinical
# 6795               9-aminoacridine    Preclinical
# 6796           9-aminocamptothecin        Phase 2
# 6797   9-anthracenecarboxylic-acid    Preclinical
#
#                                   moa  \
# 0           dopamine receptor agonist
# 1         phosphodiesterase inhibitor
# 2     benzodiazepine receptor agonist
# 3         phosphodiesterase inhibitor
# 4               tachykinin antagonist
# ...                               ...
# 6793       melatonin receptor agonist
# 6794                              NaN
# 6795                              NaN
# 6796          topoisomerase inhibitor
# 6797                              NaN
#
#                                                  target          disease_area  \
# 0     ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...  neurology/psychiatry
# 1                         PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                   NaN
# 2                                         GABBR1|GABBR2                   NaN
# 3                                           PDE4B|PDE4D                   NaN
# 4                                                 TACR1                   NaN
# ...                                                 ...                   ...
# 6793                                      MTNR1A|MTNR1B                   NaN
# 6794                                                NaN                   NaN
# 6795                                                NaN                   NaN
# 6796                                               TOP1                   NaN
# 6797                                         ANO1|CLCN1                   NaN
#
#                indication
# 0     Parkinson's Disease
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 6793                  NaN
# 6794                  NaN
# 6795                  NaN
# 6796                  NaN
# 6797                  NaN
#
# [6798 rows x 6 columns]

# %%
# ReDO Trials 
# https://www.anticancerfund.org/en/redo-trials-db

df2 = pd.read_csv('data/ReDO_Trials_DB.txt',sep='\t')
df2
# Out:
#            NCT Number                                              Title  \
# 0         NCT03047837  A Randomized, 2x2 Factorial Design Biomarker P...
# 1         NCT02969681  Vitamin C Intravenously With Chemotherapy in A...
# 2         NCT02497638      LIpitor and biGuanide to Androgen Delay Trial
# 3         NCT03275376  Statin Combination Therapy in Patients Receivi...
# 4         NCT03980249  Anti-Cancer Effects of Carvedilol With Standar...
# ..                ...                                                ...
# 902  ChiCTR2200061789  Fasudil hydrochloride in the treatment of gene...
# 903  ChiCTR2200066615  The effect of intraoperative intravenous lidoc...
# 904  ChiCTR2200065595  Exploratory Clinical Study on Mifepristone for...
# 905  ChiCTR2300068631  Oral aminophylline combined with sunitinib mal...
# 906  ChiCTR2300068563  lidocaine Effects on neutrophil extracellular ...
#
#       Acronym              Status  \
# 0      ASAMET          Recruiting
# 1    Vitality          Recruiting
# 2      LIGAND  Not yet recruiting
# 3         NaN          Recruiting
# 4         NaN  Not yet recruiting
# ..        ...                 ...
# 902       NaN             Pending
# 903       NaN             Pending
# 904       NaN             Pending
# 905       NaN          Recruiting
# 906       NaN             Pending
#
#                                             Conditions  \
# 0                  Tertiary Prevention in Colon Cancer
# 1                                 Colorectal Neoplasms
# 2                                      Prostate Cancer
# 3                     Overall Survival|Tumor Responses
# 4                 Glioblastoma|Glioblastoma Multiforme
# ..                                                 ...
# 902                                       Ovary cancer
# 903                                        Lung cancer
# 904                             Recurrent Glioblastoma
# 905  locally advanced unresectable renal clear cell...
# 906                                      breast cancer
#
#                                          Interventions  \
# 0    Drug: Aspirin (ASA) + Metformin (MET); Drug: A...
# 1              Drug: ascorbic acid; Drug: Chemotherapy
# 2    Drug: Metformin; Drug: Atorvastatin; Drug: Pla...
# 3    Drug: Atorvastatin 10mg; Drug: Placebo Oral Ta...
# 4                                     Drug: Carvedilol
# ..                                                 ...
# 902  first group:Fasudil Hydrochloride Injection;se...
# 903  Lidocaine group:Intraoperative intravenous lid...
# 904    treatment group:Administration of Mifepristone;
# 905  Test group:Aminophylline combined with sunitin...
# 906  Sevoflurane anesthesia experimental group:lido...
#
#                                       Outcome Measures  \
# 0    NF B; pS6K, p53, beta-catenin, PI3K; IL-6, CRP...
# 1    Progression Free Survival; Overall Survival; R...
# 2    Time to disease progression (defined as PSA ri...
# 3    Overall survival; Best tumor response; Progres...
# 4    Survival curve of overall survival; Survival c...
# ..                                                 ...
# 902  Number of treatment courses received;Overall s...
# 903            Overall survival;Disease free survival;
# 904  complete blood count;liver function test;kidne...
# 905                         Progression-free survival;
# 906                         MPO;H3Cit;NE;MMP-9;VEGF-A;
#
#                                               Sponsors  Gender  \
# 0                   Ente Ospedaliero Ospedali Galliera     All
# 1                               Sun Yat-sen University     All
# 2                   University Health Network, Toronto    Male
# 3                   Taichung Veterans General Hospital     All
# 4    West Virginia University; NovoCure Ltd.; West ...     All
# ..                                                 ...     ...
# 902        Tianjin Medical University General Hospital  Female
# 903               Zhongshan Hospital, Fudan University     All
# 904                 Huashan Hospital, Fudan University     All
# 905  Shanghai Sixth People's Hospital Affiliated to...     All
# 906     General Hospital of Ningxia Medical University  Female
#
#                                              Age  ... Multi-Arm Pediatric  \
# 0    18 Years to 80 Years   (Adult, Older Adult)  ...         N         N
# 1    18 Years to 75 Years   (Adult, Older Adult)  ...         N         N
# 2    18 Years to 80 Years   (Adult, Older Adult)  ...         N         N
# 3      40 Years and older   (Adult, Older Adult)  ...         N         N
# 4      18 Years and older   (Adult, Older Adult)  ...         N         N
# ..                                           ...  ...       ...       ...
# 902                                            -  ...         N         N
# 903                                            -  ...         N         N
# 904                                         18 -  ...         N         N
# 905                                      18 - 70  ...         N         N
# 906                                      18 - 70  ...         N         N
#
#         Country_PI    Cancer_Group                  Cancer_Type  \
# 0            Italy              GI  Colon Cancer; Rectal Cancer
# 1            China              GI                 Colon Cancer
# 2           Canada      Urological              Prostate Cancer
# 3           Taiwan              GI                 Liver Cancer
# 4    United States             CNS                 Glioblastoma
# ..             ...             ...                          ...
# 902          China  Gynaecological    Ovarian Epithelial Cancer
# 903          China            Lung             Any lung cancers
# 904          China             CNS                 Glioblastoma
# 905          China      Urological         Renal Cell Carcinoma
# 906          China          Breast            Any Breast Cancer
#
#                             Drug_INN       Primary-EP                  Phase  \
# 0    Acetylsalicylic Acid; Metformin        Biomarker                Phase 2
# 1                      Ascorbic acid              PFS                Phase 3
# 2            Atorvastatin; Metformin              PFS                Phase 2
# 3                       Atorvastatin               OS                Phase 2
# 4                         Carvedilol               OS                Phase 1
# ..                               ...              ...                    ...
# 902                          Fasudil          PFS; OS  Not available/Missing
# 903                        Lidocaine  OS; DFS/RFS/EFS  Not available/Missing
# 904                     Mifepristone        Biomarker  Not available/Missing
# 905                    Aminophylline              PFS  Not available/Missing
# 906                        Lidocaine        Biomarker  Not available/Missing
#
#                   DrugBank Removed
# 0         DB00210; DB06800       N
# 1                  DB00335       N
# 2         DB01117; DB06800       N
# 3                  DB01117       N
# 4                  DB00567       N
# ..                     ...     ...
# 902                DB00800       N
# 903  Not found in DrugBank       N
# 904                DB00370       N
# 905                DB01118       N
# 906  Not found in DrugBank       N
#
# [907 rows x 40 columns]

# %%
# repoDB (Drug Repositioning Database)
# http://apps.chiragjpgroup.org/repoDB/

df3 = pd.read_csv('data/full-repodb.csv',sep=',',header=0)
df3
# Out:
#           drug_name  drug_id  \
# 0         Lepirudin  DB00001
# 1         Cetuximab  DB00002
# 2         Cetuximab  DB00002
# 3         Cetuximab  DB00002
# 4         Cetuximab  DB00002
# ...             ...      ...
# 10557  Temozolomide  DB00853
# 10558     Dasatinib  DB01254
# 10559   Dacarbazine  DB00851
# 10560  Temozolomide  DB00853
# 10561     Dasatinib  DB01254
#
#                                                ind_name    ind_id  \
# 0      Heparin-induced thrombocytopenia with thrombosis  C0272275
# 1                      Squamous cell carcinoma of mouth  C0585362
# 2                       Squamous cell carcinoma of nose  C3163899
# 3                    Squamous cell carcinoma of pharynx  C1319317
# 4                     Laryngeal Squamous Cell Carcinoma  C0280324
# ...                                                 ...       ...
# 10557                                      CNS disorder  C0007682
# 10558                                      CNS disorder  C0007682
# 10559                                    Brain Diseases  C0006111
# 10560                                    Brain Diseases  C0006111
# 10561                                    Brain Diseases  C0006111
#
#                NCT     status    phase  \
# 0              NaN   Approved      NaN
# 1              NaN   Approved      NaN
# 2              NaN   Approved      NaN
# 3              NaN   Approved      NaN
# 4              NaN   Approved      NaN
# ...            ...        ...      ...
# 10557  NCT02661113  Withdrawn  Phase 2
# 10558  NCT02661113  Withdrawn  Phase 2
# 10559  NCT02661113  Withdrawn  Phase 2
# 10560  NCT02661113  Withdrawn  Phase 2
# 10561  NCT02661113  Withdrawn  Phase 2
#
#                                           DetailedStatus
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10557  Sponsor withdrew support; Study did not progre...
# 10558  Sponsor withdrew support; Study did not progre...
# 10559  Sponsor withdrew support; Study did not progre...
# 10560  Sponsor withdrew support; Study did not progre...
# 10561  Sponsor withdrew support; Study did not progre...
#
# [10562 rows x 8 columns]

# %% [markdown]
# ### The Repurposing Hub

# %% [markdown]
# #### Normalization
# NOTE: Chose to normalize this way to make only one set of therapy normalizer calls instead of dealing with apply errors or requests errors.

# %%
# Grab all relevant data from the therapy normalizer
results_list = []
input_list = df['pert_iname']

for drug in tqdm(input_list):
    results_list.append(normalize(drug))

results_list
# Out:
# 100%|██████████| 6798/6798 [17:59<00:00,  6.29it/s]
# [['(R)-(-)-apomorphine', None, None],
#  ['(R)-(-)-rolipram', 60, 'ncit:C72842'],
#  ['(R)-baclofen', 60, 'rxcui:1292'],
#  ['(S)-(+)-rolipram', None, None],
#  ['[sar9,met(o2)11]-substance-p', None, None],
#  ['A-1070722', None, None],
#  ['A-1120', None, None],
#  ['A-317491', 80, 'iuphar.ligand:4115'],
#  ['A-33903', 60, 'chembl:CHEMBL204738'],
#  ['A-366', 80, 'iuphar.ligand:8238'],
#  ['A-381393', 80, 'iuphar.ligand:8441'],
#  ['A-412997', 60, 'iuphar.ligand:3301'],
#  ['A-438079', 60, 'iuphar.ligand:4118'],
#  ['A-485', 80, 'chembl:CHEMBL4282264'],
#  ['A-582941', 80, 'iuphar.ligand:3995'],
#  ['A-61603', 60, 'iuphar.ligand:480'],
#  ['A-674563', 80, 'drugbank:DB08568'],
#  ['A-7', None, None],
#  ['A-769662', 80, 'iuphar.ligand:10069'],
#  ['A-784168', None, None],
#  ['A-803467', 80, 'iuphar.ligand:5734'],
#  ['A-804598', 60, 'iuphar.ligand:4121'],
#  ['A-839977', 60, 'iuphar.ligand:4122'],
#  ['A-867744', 80, 'iuphar.ligand:3986'],
#  ['A-887826', None, None],
#  ['A-922500', None, None],
#  ['A-939572', None, None],
#  ['A-967079', 80, 'iuphar.ligand:6280'],
#  ['A-987306', 60, 'chembl:CHEMBL1935450'],
#  ['AA-29504', None, None],
#  ['AAI101', 60, 'iuphar.ligand:12188'],
#  ['AB-423', None, None],
#  ['abacavir', 80, 'rxcui:190521'],
#  ['abafungin', 80, 'ncit:C72951'],
#  ['abamectin', 80, 'ncit:C95196'],
#  ['abametapir', 80, 'rxcui:2475532'],
#  ['abarelix', 80, 'rxcui:301739'],
#  ['ABBV-744', 80, 'iuphar.ligand:10730'],
#  ['ABC-294640', 80, 'iuphar.ligand:6624'],
#  ['abemaciclib', 80, 'rxcui:1946825'],
#  ['abiraterone', 80, 'rxcui:1100071'],
#  ['abiraterone-acetate', None, None],
#  ['ABT-072', 80, 'drugbank:DB15156'],
#  ['ABT-202', None, None],
#  ['ABT-239', 80, 'iuphar.ligand:1218'],
#  ['ABT-491', 80, 'iuphar.ligand:1850'],
#  ['ABT-639', 80, 'drugbank:DB15055'],
#  ['ABT-702', 60, 'iuphar.ligand:5131'],
#  ['ABT-724', 80, 'chembl:CHEMBL440687'],
#  ['ABT-737', 80, 'iuphar.ligand:8320'],
#  ['ABT-751', 80, 'drugbank:DB12254'],
#  ['ABX-1431', 80, 'drugbank:DB16036'],
#  ['ABX464', 60, 'ncit:C158506'],
#  ['AC-186', 80, 'iuphar.ligand:8897'],
#  ['AC-261066', 60, 'iuphar.ligand:4054'],
#  ['AC-264613', 60, 'iuphar.ligand:9460'],
#  ['AC-55541', 80, 'iuphar.ligand:9456'],
#  ['AC-55649', 60, 'iuphar.ligand:4055'],
#  ['AC-710', 60, 'iuphar.ligand:8095'],
#  ['AC-7954-(+/-)', None, None],
#  ['acadesine', 80, 'ncit:C71537'],
#  ['acalabrutinib', 80, 'rxcui:1986808'],
#  ['acalisib', 80, 'ncit:C103277'],
#  ['acamprosate', 80, 'rxcui:152761'],
#  ['acarbose', 80, 'rxcui:16681'],
#  ['ACDPP', 80, 'iuphar.ligand:3388'],
#  ['acebilustat', 80, 'ncit:C169757'],
#  ['acebutolol', 80, 'rxcui:149'],
#  ['acecainide', 80, 'ncit:C75125'],
#  ['aceclidine', 80, 'ncit:C81044'],
#  ['aceclofenac', 80, 'rxcui:16689'],
#  ['acedapsone', 80, 'ncit:C76985'],
#  ['acedoben', 80, 'ncit:C74109'],
#  ['acefylline', 80, 'ncit:C96200'],
#  ['aceglutamide', 80, 'rxcui:1426379'],
#  ['acelarin', 80, 'iuphar.ligand:7389'],
#  ['acemetacin', 80, 'rxcui:16695'],
#  ['aceneuramic-acid', None, None],
#  ['acenocoumarol', 80, 'rxcui:154'],
#  ['acepromazine', 80, 'rxcui:155'],
#  ['acesulfame-potassium', None, None],
#  ['acetanilide', 80, 'rxcui:162'],
#  ['acetarsol', 80, 'ncit:C61621'],
#  ['acetazolamide', 80, 'rxcui:167'],
#  ['acetohexamide', 80, 'rxcui:173'],
#  ['acetohydroxamic-acid', None, None],
#  ['acetophenazine', 80, 'rxcui:16735'],
#  ['acetriazoic-acid', None, None],
#  ['acetyl-farnesyl-cysteine', None, None],
#  ['acetyl-l-leucine', 80, 'chembl:CHEMBL56021'],
#  ['acetyl-11-keto-beta-boswellic-acid', None, None],
#  ['acetylcholine', 80, 'rxcui:194'],
#  ['acetylcysteine', 80, 'rxcui:197'],
#  ['acetylsalicylsalicylic-acid', None, None],
#  ['acetylspiramycin', 80, 'chemidplus:24916-51-6'],
#  ['acexamic-acid', None, None],
#  ['acifran', 80, 'ncit:C81534'],
#  ['acipimox', 80, 'rxcui:16817'],
#  ['acitazanolast', 80, 'ncit:C74133'],
#  ['acitretin', 80, 'rxcui:16818'],
#  ['acivicin', 80, 'ncit:C986'],
#  ['aclarubicin', 80, 'rxcui:239'],
#  ['aclidinium', 80, 'rxcui:1303098'],
#  ['acolbifene', 80, 'ncit:C64183'],
#  ['acoziborole', 80, 'ncit:C166573'],
#  ['ACPC', 60, 'ncit:C404'],
#  ['acriflavine', 80, 'rxcui:249'],
#  ['acriflavinium', 60, 'chembl:CHEMBL2360628'],
#  ['acrisorcin', 80, 'rxcui:89729'],
#  ['acrivastine', 80, 'rxcui:19959'],
#  ['acrylate', 80, 'rxcui:1364500'],
#  ['ACT-132577', 60, 'ncit:C174728'],
#  ['ACT-462206', 80, 'iuphar.ligand:9303'],
#  ['actarit', 80, 'ncit:C73298'],
#  ['ACTB-1003', 60, 'ncit:C164211'],
#  ['actinomycin-d', 60, 'rxcui:3100'],
#  ['actinoquinol', 80, 'ncit:C76254'],
#  ['acumapimod', 80, 'ncit:C166567'],
#  ['ACY-1215', 60, 'ncit:C96431'],
#  ['acyclovir', 80, 'rxcui:281'],
#  ['AC1NDSS5', None, None],
#  ['AC260584', 60, 'iuphar.ligand:334'],
#  ['AD-5467', None, None],
#  ['adapalene', 80, 'rxcui:60223'],
#  ['adaprev', None, None],
#  ['adaptavir', 80, 'iuphar.ligand:11692'],
#  ['adarotene', 80, 'ncit:C96706'],
#  ['adatanserin', 80, 'ncit:C75981'],
#  ['adavivint', 60, 'chembl:CHEMBL4297639'],
#  ['ADD-233089', None, None],
#  ['adefovir', 80, 'rxcui:16521'],
#  ['adefovir-dipivoxil', None, None],
#  ['adelmidrol', 80, 'ncit:C74098'],
#  ['ademetionine', 80, 'ncit:C100098'],
#  ['adenine', 80, 'rxcui:290'],
#  ['adenosine', 80, 'rxcui:296'],
#  ['adenosine-phosphate', None, None],
#  ['adenosine-triphosphate', None, None],
#  ['adiphenine', 80, 'rxcui:333'],
#  ['adipic-acid', None, None],
#  ['adiporon', None, None],
#  ['ADL5859', 80, 'drugbank:DB05050'],
#  ['adomeglivant', 80, 'ncit:C166989'],
#  ['adoprazine', 80, 'ncit:C81482'],
#  ['adrafinil', 80, 'rxcui:45938'],
#  ['adrenalone', 80, 'rxcui:17073'],
#  ['adrenosterone', None, None],
#  ['ADX-10059', 60, 'chembl:CHEMBL3545036'],
#  ['ADX-47273', 80, 'iuphar.ligand:1420'],
#  ['AEE788', 80, 'iuphar.ligand:7643'],
#  ['AEG3482', None, None],
#  ['afalanine', 80, 'ncit:C72682'],
#  ['afamelanotide', 80, 'rxcui:2262250'],
#  ['afatinib', 80, 'rxcui:1430438'],
#  ['afimoxifene', 80, 'ncit:C975'],
#  ['afloqualone', 80, 'ncit:C83522'],
#  ['AFN-1252', 80, 'drugbank:DB12658'],
#  ['afobazole', 60, 'ncit:C81617'],
#  ['AF38469', None, None],
#  ['AG-1024', 60, 'iuphar.ligand:5912'],
#  ['AG-14361', 60, 'iuphar.ligand:8094'],
#  ['AG-490', 60, 'iuphar.ligand:5916'],
#  ['AG-555', 60, 'chembl:CHEMBL53898'],
#  ['AG-556', None, None],
#  ['AGI-5198', 80, 'iuphar.ligand:9240'],
#  ['AGI-6780', None, None],
#  ['AGM-1470', 60, 'ncit:C1298'],
#  ['agmatine', 80, 'drugbank:DB08838'],
#  ['AGN-192403', None, None],
#  ['AGN-194310', None, None],
#  ['AGN-195183', 60, 'ncit:C77899'],
#  ['agomelatine', 80, 'ncit:C72684'],
#  ['AGP-103', None, None],
#  ['AH-7614', None, None],
#  ['AH11110', 60, 'iuphar.ligand:8461'],
#  ['AH6809', 80, 'iuphar.ligand:1896'],
#  ['AI-10-49', None, None],
#  ['AIM-100', None, None],
#  ['ajmaline', 80, 'rxcui:423'],
#  ['AJ76-(+)', None, None],
#  ['AK-7', None, None],
#  ['AKBA', 80, 'chembl:CHEMBL237111'],
#  ['aklomide', 80, 'ncit:C76410'],
#  ['AL-8697', None, None],
#  ['alacepril', 80, 'ncit:C75021'],
#  ['alafosfalin', 80, 'ncit:C74137'],
#  ['alagebrium', 80, 'drugbank:DB12497'],
#  ['alanine', 80, 'rxcui:426'],
#  ['alanosine', 80, 'ncit:C994'],
#  ['alantolactone', 60, 'chembl:CHEMBL136356'],
#  ['alaproclate', 80, 'ncit:C72685'],
#  ['alarelin', 80, 'iuphar.ligand:9342'],
#  ['albendazole', 80, 'rxcui:430'],
#  ['albendazole-oxide', None, None],
#  ['albuterol', 80, 'rxcui:142153'],
#  ['alcaftadine', 80, 'rxcui:1000082'],
#  ['alclofenac', 80, 'ncit:C174701'],
#  ['alclometasone-dipropionate', None, None],
#  ['alcuronium', 80, 'rxcui:460'],
#  ['alda-1', None, None],
#  ['aldoxorubicin', 80, 'ncit:C68921'],
#  ['alectinib', 80, 'rxcui:1727455'],
#  ['alendronate', 80, 'rxcui:203152'],
#  ['alexidine', 80, 'ncit:C80849'],
#  ['alfacalcidol', 80, 'rxcui:12062'],
#  ['alfadolone-acetate', None, None],
#  ['alfuzosin', 80, 'rxcui:17300'],
#  ['algestone-acetophenide', None, None],
#  ['alibendol', 80, 'rxcui:236219'],
#  ['alimemazine', 80, 'rxcui:10825'],
#  ['alinidine', 80, 'ncit:C72571'],
#  ['alisertib', 80, 'ncit:C71717'],
#  ['aliskiren-hemifumarate', None, None],
#  ['alisporivir', 80, 'ncit:C169774'],
#  ['alizapride', 80, 'rxcui:17311'],
#  ['alizarin', None, None],
#  ['allantoin', 80, 'rxcui:508'],
#  ['allicin', 80, 'drugbank:DB11780'],
#  ['allopurinol', 80, 'rxcui:519'],
#  ['allopurinol-riboside', None, None],
#  ['allylestrenol', 80, 'rxcui:525'],
#  ['allylisothiocyanate', None, None],
#  ['allylthiourea', 80, 'rxcui:1318494'],
#  ['almitrine', 80, 'rxcui:528'],
#  ['almorexant', 80, 'ncit:C87423'],
#  ['almotriptan', 80, 'rxcui:279645'],
#  ['aloe-emodin', 80, 'chembl:CHEMBL40275'],
#  ['alogliptin', 80, 'rxcui:1368001'],
#  ['aloin', 80, 'ncit:C76760'],
#  ['aloperine', None, None],
#  ['alosetron', 80, 'rxcui:85248'],
#  ['alovudine', 80, 'ncit:C65226'],
#  ['aloxistatin', 80, 'ncit:C76907'],
#  ['alpelisib', 80, 'rxcui:2169285'],
#  ['alpha-asarone', 80, 'rxcui:2375532'],
#  ['alpha-D-glucopyranose', 80, 'rxcui:1800492'],
#  ['alpha-glucosyl-hesperidin', None, None],
#  ['alpha-linolenic-acid', None, None],
#  ['alpha-methylhistamine-dihydrobromide-(R)-(-)', None, None],
#  ['alpha-methylhistamine-dihydrobromide-(S)-(+)', None, None],
#  ['alpha-methylserotonin', None, None],
#  ['alpha-tochopherol', 80, 'chembl:CHEMBL49563'],
#  ['alpha-tochopheryl-acetate', None, None],
#  ['alpidem', 80, 'ncit:C80669'],
#  ['alprenolol', 80, 'rxcui:597'],
#  ['alprostadil', 80, 'rxcui:598'],
#  ['alrestatin', 80, 'ncit:C72917'],
#  ['ALS-8112', 80, 'chembl:CHEMBL3417243'],
#  ['ALS-8176', 60, 'chembl:CHEMBL3417258'],
#  ['altanserin', 80, 'ncit:C77258'],
#  ['althiazide', 80, 'rxcui:17599'],
#  ['altinicline', 80, 'ncit:C77841'],
#  ['altiratinib', 80, 'ncit:C118290'],
#  ['altrenogest', 80, 'rxcui:1314612'],
#  ['altretamine', 80, 'rxcui:5296'],
#  ['alverine', 80, 'rxcui:17627'],
#  ['alvespimycin', 80, 'ncit:C38142'],
#  ['alvimopan', 80, 'rxcui:1516803'],
#  ['alvocidib', 80, 'ncit:C74940'],
#  ['ALX-40-4C', None, None],
#  ['ALX-5407', 60, 'iuphar.ligand:4618'],
#  ['AM-1241', 60, 'iuphar.ligand:3316'],
#  ['AM-24', None, None],
#  ['AM-251', 60, 'iuphar.ligand:3317'],
#  ['AM-281', 60, 'iuphar.ligand:741'],
#  ['AM-404', 60, 'chembl:CHEMBL39878'],
#  ['AM-580', None, None],
#  ['AM-630', 80, 'iuphar.ligand:750'],
#  ['AM-92016', 60, 'chembl:CHEMBL43527'],
#  ['amantadine', 80, 'rxcui:282415'],
#  ['ambazone', 80, 'ncit:C72627'],
#  ['ambenonium', 80, 'rxcui:623'],
#  ['ambrisentan', 80, 'rxcui:358274'],
#  ['ambroxol', 80, 'rxcui:625'],
#  ['amcasertib', 80, 'ncit:C104745'],
#  ['amcinonide', 80, 'rxcui:17652'],
#  ['AMD-3465', 60, 'chembl:CHEMBL477121'],
#  ['amdinocillin', 80, 'rxcui:626'],
#  ['AMD11070', 60, 'ncit:C126660'],
#  ['ameltolide', 80, 'ncit:C81472'],
#  ['amenamevir', 80, 'ncit:C90782'],
#  ['ametantrone', 80, 'ncit:C1342'],
#  ['amezinium', 80, 'rxcui:17665'],
#  ['amfenac', 80, 'ncit:C73071'],
#  ['amflutizole', 80, 'ncit:C91009'],
#  ['AMG-PERK-44', None, None],
#  ['AMG-176', 60, 'chembl:CHEMBL4446378'],
#  ['AMG-208', 80, 'drugbank:DB08079'],
#  ['AMG-232', 80, 'ncit:C116624'],
#  ['AMG-319', 80, 'chembl:CHEMBL3545048'],
#  ['AMG-337', 80, 'drugbank:DB15639'],
#  ['AMG-487', 60, 'chembl:CHEMBL397983'],
#  ['AMG-487-(+/-)', None, None],
#  ['AMG-510', 60, 'rxcui:2550714'],
#  ['AMG-517', 80, 'iuphar.ligand:4129'],
#  ['AMG-548', 80, 'chembl:CHEMBL585902'],
#  ['AMG-837', 80, 'iuphar.ligand:6485'],
#  ['AMG-925', None, None],
#  ['AMG-9810', 60, 'iuphar.ligand:6347'],
#  ['AMG319', 80, 'iuphar.ligand:8917'],
#  ['AMG458', None, None],
#  ['AMG900', 60, 'iuphar.ligand:8060'],
#  ['AMI-1', 80, 'iuphar.ligand:7028'],
#  ['amibegron', 80, 'ncit:C77932'],
#  ['amidopyrine', 60, 'rxcui:695'],
#  ['amifampridine', 80, 'rxcui:2106338'],
#  ['amiflamine', 80, 'ncit:C72695'],
#  ['amifostine', 80, 'rxcui:1545987'],
#  ['amikacin', 80, 'rxcui:641'],
#  ['amiloride', 80, 'rxcui:644'],
#  ['amineptine', 80, 'rxcui:17698'],
#  ['aminocaproic-acid', None, None],
#  ['aminoglutethimide', 80, 'rxcui:677'],
#  ['aminoguanidine', 80, 'rxcui:1311670'],
#  ['aminohydroxybutyric-acid', None, None],
#  ['aminolevulinic-acid-benzyl-ester', None, None],
#  ['aminomethyltransferase', None, None],
#  ['aminopentamide', 80, 'rxcui:1006397'],
#  ['aminophylline', 80, 'rxcui:689'],
#  ['aminopterin', 80, 'rxcui:1440264'],
#  ['aminopurvalanol-a', None, None],
#  ['aminosalicylate', 80, 'rxcui:113374'],
#  ['aminothiadiazole', 80, 'ncit:C1335'],
#  ['aminothiazole', 80, 'ncit:C74177'],
#  ['amiodarone', 80, 'rxcui:203114'],
#  ['amiprilose', 80, 'ncit:C76690'],
#  ['amiselimod', 80, 'ncit:C166641'],
#  ['amisulpride', 80, 'rxcui:46303'],
#  ['amitifadine', 80, 'ncit:C169780'],
#  ['amitraz', 80, 'rxcui:17763'],
#  ['amitriptyline', 80, 'rxcui:203168'],
#  ['amlexanox', 80, 'rxcui:46307'],
#  ['amlodipine', 80, 'rxcui:104416'],
#  ['ammonium-glycyrrhizinate', None, None],
#  ['ammonium-lactate', None, None],
#  ['ammonium-perfluorocaprylate', None, None],
#  ['AMN-082', 60, 'iuphar.ligand:1441'],
#  ['amodiaquine', 80, 'rxcui:720'],
#  ['amonafide', 80, 'rxcui:1440270'],
#  ['amorolfine', 80, 'rxcui:17804'],
#  ['amoxapine', 80, 'rxcui:722'],
#  ['amoxicillin', 80, 'rxcui:1297882'],
#  ['AMPA-(RS)', None, None],
#  ['AMPA-(S)', None, None],
#  ['ampalex', 60, 'iuphar.ligand:4165'],
#  ['amperozide', 80, 'ncit:C74191'],
#  ['amphotericin-b', None, None],
#  ['ampicillin', 80, 'rxcui:221058'],
#  ['ampiroxicam', 80, 'ncit:C73073'],
#  ['amprenavir', 80, 'rxcui:228656'],
#  ['amprolium', 80, 'rxcui:1006654'],
#  ['ampyrone', 80, 'chembl:CHEMBL1165011'],
#  ['amrinone', 80, 'rxcui:738'],
#  ['amrubicin', 80, 'ncit:C80089'],
#  ['amsacrine', 80, 'rxcui:739'],
#  ['amthamine', 80, 'iuphar.ligand:4025'],
#  ['amtolmetin-guacil', None, None],
#  ['amuvatinib', 80, 'ncit:C71750'],
#  ['amygdalin', 80, 'rxcui:1371051'],
#  ['amyl-nitrite', None, None],
#  ['amyleine', None, None],
#  ['amylene-hydrate', None, None],
#  ['AMZ30', None, None],
#  ['AM095', 80, 'iuphar.ligand:6988'],
#  ['AM211', 60, 'chembl:CHEMBL2181753'],
#  ['AM679', None, None],
#  ['ANA-12', None, None],
#  ['anabasine', 80, 'chembl:CHEMBL1526229'],
#  ['anacetrapib', 80, 'ncit:C75251'],
#  ['anagliptin', 80, 'ncit:C96202'],
#  ['anagrelide', 80, 'rxcui:236612'],
#  ['anamorelin', 80, 'ncit:C52197'],
#  ['anandamide', 80, 'iuphar.ligand:2364'],
#  ['anastrozole', 80, 'rxcui:84857'],
#  ['andarine', 80, 'drugbank:DB07423'],
#  ['andrographolide', 80, 'ncit:C61637'],
#  ['androstenone', 80, 'ncit:C95969'],
#  ['androsterone', 80, 'rxcui:1312359'],
#  ['anecortave-acetate', None, None],
#  ['anethole', 80, 'rxcui:17881'],
#  ['anethole-trithione', None, None],
#  ['anguidine', 80, 'ncit:C1068'],
#  ['anidulafungin', 80, 'rxcui:341018'],
#  ['aniracetam', 80, 'rxcui:17939'],
#  ['anisindione', 80, 'rxcui:17941'],
#  ['anisodamine', 80, 'drugbank:DB11785'],
#  ['anisomycin', 80, 'ncit:C95312'],
#  ['anisotropine', 80, 'rxcui:89780'],
#  ['anlotinib', 80, 'ncit:C138997'],
#  ['anpirtoline', 80, 'ncit:C72106'],
#  ['ANR-94', None, None],
#  ['ansamitocin-p-3', None, None],
#  ['antagonist-g', None, None],
#  ['antalarmin', 80, 'iuphar.ligand:3489'],
#  ['antazoline', 80, 'rxcui:865'],
#  ['anthralin', 80, 'rxcui:873'],
#  ['anthraquinone', 80, 'chembl:CHEMBL55659'],
#  ['antimony-potassium', None, None],
#  ['antimonyl', None, None],
#  ['antimycin-A', None, None],
#  ['antioxine', None, None],
#  ['AN2718', 60, 'chembl:CHEMBL211538'],
#  ['AP-18', 60, 'iuphar.ligand:4134'],
#  ['apabetalone', 80, 'ncit:C171748'],
#  ['apafant', 80, 'ncit:C77989'],
#  ['apalutamide', 80, 'rxcui:1999574'],
#  ['apararenone', 80, 'ncit:C171675'],
#  ['apatinib', 80, 'hemonc:40'],
#  ['APC-100', 80, 'chembl:CHEMBL37676'],
#  ['APcK-110', None, None],
#  ['APD597', 60, 'iuphar.ligand:5727'],
#  ['APD668', 80, 'drugbank:DB05166'],
#  ['aphidicolin', 80, 'chembl:CHEMBL29711'],
#  ['API-001', None, None],
#  ['API-1', None, None],
#  ['apigenin', 80, 'rxcui:1368130'],
#  ['apixaban', 80, 'rxcui:1364430'],
#  ['apocynin', 80, 'drugbank:DB12618'],
#  ['apoptosis-activator-II', None, None],
#  ['APR-246', 80, 'ncit:C85465'],
#  ['apraclonidine', 80, 'rxcui:14845'],
#  ['apramycin', 80, 'ncit:C78789'],
#  ['apratastat', 80, 'ncit:C76767'],
#  ['apremilast', 80, 'rxcui:1492727'],
#  ['aprepitant', 80, 'rxcui:358255'],
#  ['apricitabine', 80, 'ncit:C79871'],
#  ['aprindine', 80, 'rxcui:1054'],
#  ['apronal', 80, 'chembl:CHEMBL509282'],
#  ['aptiganel', 80, 'ncit:C79861'],
#  ['APTO-253', 80, 'chembl:CHEMBL4297261'],
#  ['APY-29', None, None],
#  ['apyramide', None, None],
#  ['APY0201', None, None],
#  ['AP1903', 60, 'ncit:C82412'],
#  ['AP26113', 60, 'rxcui:1921217'],
#  ['AQ-RA741', None, None],
#  ['AQ-13', 80, 'iuphar.ligand:10391'],
#  ['AQW-051', None, None],
#  ['AR-A014418', 60, 'drugbank:DB01950'],
#  ['AR-C155858', None, None],
#  ['AR-12', 80, 'iuphar.ligand:8005'],
#  ['AR-42', 80, 'drugbank:DB12707'],
#  ['arachidonic-acid', None, None],
#  ['aramchol', 80, 'drugbank:DB11860'],
#  ['arbidol', 60, 'ncit:C152799'],
#  ['arbutin', 80, 'rxcui:1367175'],
#  ['ARC-239', 80, 'iuphar.ligand:524'],
#  ['arctigenin', 80, 'chembl:CHEMBL435734'],
#  ['arcyriaflavin-a', None, None],
#  ['ardeparin', 80, 'rxcui:104466'],
#  ['arecaidine-but-2-ynyl-ester', None, None],
#  ['arecaidine-propargyl-ester', None, None],
#  ['arecoline', 80, 'ncit:C76610'],
#  ['argatroban', 80, 'rxcui:15202'],
#  ['argireline', 60, 'rxcui:1314329'],
#  ['arglabin', 80, 'chembl:CHEMBL2206431'],
#  ['aripiprazole', 80, 'rxcui:1673265'],
#  ['aripiprazole-lauroxil', None, None],
#  ['arofylline', 80, 'ncit:C74223'],
#  ['arotinolol', 80, 'ncit:C72609'],
#  ['ARQ-092', 60, 'iuphar.ligand:9429'],
#  ['ARQ-621', 80, 'chembl:CHEMBL4303449'],
#  ['ARRY-334543', 60, 'ncit:C62530'],
#  ['arsanilic-acid', None, None],
#  ['arsenic-trioxide', None, None],
#  ['artemether', 80, 'rxcui:18343'],
#  ['artemisinin', 80, 'rxcui:2367409'],
#  ['artemotil', 80, 'ncit:C73002'],
#  ['artesunate', 80, 'rxcui:18346'],
#  ['articaine', 80, 'rxcui:592464'],
#  ['arundic-acid', None, None],
#  ['ARV-825', None, None],
#  ['AS-1269574', 60, 'iuphar.ligand:4027'],
#  ['AS-1892802', None, None],
#  ['AS-1949490', 60, 'iuphar.ligand:8878'],
#  ['AS-2034178', None, None],
#  ['AS-2444697', None, None],
#  ['AS-252424', 80, 'iuphar.ligand:10578'],
#  ['AS-604850', 60, 'chembl:CHEMBL2216899'],
#  ['AS-703026', 60, 'ncit:C84864'],
#  ['AS-77', None, None],
#  ['ASA-404', 60, 'ncit:C2504'],
#  ['asapiprant', 80, 'ncit:C171866'],
#  ['asaraldehyde', 80, 'chembl:CHEMBL1164301'],
#  ['ASC-J9', None, None],
#  ['asciminib', 80, 'rxcui:2584304'],
#  ['ascomycin', 80, 'chembl:CHEMBL8597'],
#  ['ascorbic-acid', None, None],
#  ['asenapine', 80, 'rxcui:784649'],
#  ['asiatic-acid', None, None],
#  ['asimadoline', 80, 'ncit:C72137'],
#  ['asivatrep', 80, 'ncit:C166704'],
#  ['ASP-2535', 60, 'iuphar.ligand:11296'],
#  ['ASP-6537', 60, 'iuphar.ligand:10241'],
#  ['ASP-9521', 60, 'ncit:C133224'],
#  ['aspartame', 80, 'rxcui:1311524'],
#  ['aspirin', 80, 'rxcui:1191'],
#  ['ASP3026', 60, 'ncit:C116727'],
#  ['AST-1306', 60, 'ncit:C179280'],
#  ['astaxanthin', 80, 'rxcui:18451'],
#  ['astemizole', 80, 'rxcui:42328'],
#  ['astilbin', 80, 'chembl:CHEMBL486017'],
#  ['astragaloside-a', None, None],
#  ['ASTX660', 80, 'drugbank:DB16160'],
#  ['asunaprevir', 80, 'rxcui:1652103'],
#  ['asymmetrical-dimethylarginine', None, None],
#  ['AT-1015', None, None],
#  ['AT-406', 80, 'drugbank:DB16305'],
#  ['AT-7519', 80, 'drugbank:DB08142'],
#  ['AT-9283', 80, 'iuphar.ligand:7949'],
#  ['ataluren', 80, 'ncit:C169791'],
#  ['atazanavir', 80, 'rxcui:343047'],
#  ['ATB-346', 80, 'drugbank:DB15377'],
#  ['atenolol-(+)', None, None],
#  ['atenolol-(+/-)', None, None],
#  ['atenolol-(-)', None, None],
#  ['atglistatin', None, None],
#  ['aticaprant', 80, 'ncit:C170144'],
#  ['atipamezole', 80, 'rxcui:18475'],
#  ['atiprimod', 80, 'ncit:C52184'],
#  ['atizoram', 80, 'ncit:C80269'],
#  ['ATN-161', 80, 'drugbank:DB05491'],
#  ['atomoxetine', 80, 'rxcui:353103'],
#  ['atorvastatin', 80, 'rxcui:1297766'],
#  ['atosiban', 80, 'rxcui:59639'],
#  ['atovaquone', 80, 'rxcui:60212'],
#  ['ATPA', 80, 'iuphar.ligand:4140'],
#  ['atractylenolide-i', None, None],
#  ['atracurium', 80, 'rxcui:1218'],
#  ['atrasentan', 80, 'ncit:C61606'],
#  ['atropine', 80, 'rxcui:1223'],
#  ['atropine-oxide', None, None],
#  ['atuveciclib', 80, 'ncit:C121456'],
#  ['AT13148', 60, 'ncit:C101786'],
#  ['AT13387', 60, 'ncit:C85454'],
#  ['AT7867', None, None],
#  ['auranofin', 80, 'rxcui:1227'],
#  ['aurora-a-inhibitor-i', None, None],
#  ['aurothioglucose', 80, 'rxcui:4980'],
#  ['AUT-1', None, None],
#  ['autotaxin-modulator-1', None, None],
#  ['AV-412', 80, 'drugbank:DB06021'],
#  ['AV-608', None, None],
#  ['avacopan', 80, 'rxcui:2572100'],
#  ['avadomide', 80, 'ncit:C160786'],
#  ['avagacestat', 80, 'ncit:C96305'],
#  ['avanafil', 80, 'rxcui:1291301'],
#  ['avapritinib', 80, 'rxcui:2272107'],
#  ['avasimibe', 80, 'ncit:C75252'],
#  ['avatrombopag', 80, 'rxcui:2045726'],
#  ['AVE-0991', 60, 'iuphar.ligand:5579'],
#  ['AVE-3085', None, None],
#  ['AVex-73', None, None],
#  ['avibactam', 80, 'rxcui:1603834'],
#  ['avitinib', 60, 'chembl:CHEMBL4297865'],
#  ['AVL-292', 60, 'ncit:C97037'],
#  ['AVN-492', None, None],
#  ['AVN-944', 80, 'drugbank:DB05500'],
#  ['avobenzone', 80, 'rxcui:45045'],
#  ['avoralstat', 80, 'ncit:C169799'],
#  ['avridine', 80, 'ncit:C76685'],
#  ['AX-024', 80, 'iuphar.ligand:11253'],
#  ['axitinib', 80, 'rxcui:1242999'],
#  ['AY-9944', 60, 'chembl:CHEMBL1513392'],
#  ['AZ-10417808', 60, 'iuphar.ligand:5143'],
#  ['AZ-10606120', 60, 'iuphar.ligand:9021'],
#  ['AZ-12080282', None, None],
#  ['AZ-628', 60, 'iuphar.ligand:8475'],
#  ['AZ-7371', 60, 'chembl:CHEMBL3109802'],
#  ['azacitidine', 80, 'rxcui:1251'],
#  ['azacyclonol', 80, 'ncit:C76502'],
#  ['azaguanine-8', 60, 'drugbank:DB01667'],
#  ['azalomycin-B', None, None],
#  ['azaperone', 80, 'rxcui:2601502'],
#  ['azapropazone', 80, 'rxcui:1029'],
#  ['azaserine', 80, 'ncit:C289'],
#  ['azasetron', 80, 'ncit:C73101'],
#  ['azatadine', 80, 'rxcui:18600'],
#  ['azathioprine', 80, 'rxcui:1256'],
#  ['AZD0156', 80, 'iuphar.ligand:9942'],
#  ['AZD1080', 80, 'iuphar.ligand:7819'],
#  ['AZD1208', 80, 'iuphar.ligand:7698'],
#  ['AZD1283', 80, 'iuphar.ligand:7360'],
#  ['AZD1390', 80, 'iuphar.ligand:11277'],
#  ['AZD1446', 80, 'chembl:CHEMBL2179529'],
#  ['AZD1480', 80, 'iuphar.ligand:5933'],
#  ['AZD1981', 80, 'iuphar.ligand:7680'],
#  ['AZD2014', 60, 'ncit:C88329'],
#  ['AZD2461', 80, 'iuphar.ligand:8472'],
#  ['AZD2858', 80, 'iuphar.ligand:8478'],
#  ['AZD3264', None, None],
#  ['AZD3463', 80, 'iuphar.ligand:7706'],
#  ['AZD3514', 80, 'chembl:CHEMBL2346976'],
#  ['AZD3759', 60, 'ncit:C118289'],
#  ['AZD3839', 80, 'iuphar.ligand:6931'],
#  ['AZD3965', 80, 'iuphar.ligand:10605'],
#  ['AZD3988', None, None],
#  ['AZD4282', None, None],
#  ['AZD4547', 80, 'iuphar.ligand:7707'],
#  ['AZD4573', 80, 'iuphar.ligand:11782'],
#  ['AZD4635', 60, 'ncit:C148039'],
#  ['AZD5069', 80, 'iuphar.ligand:8948'],
#  ['AZD5153', 60, 'ncit:C151943'],
#  ['AZD5363', 60, 'ncit:C102564'],
#  ['AZD5438', 80, 'iuphar.ligand:8473'],
#  ['AZD5582', 80, 'iuphar.ligand:7710'],
#  ['AZD5991', 80, 'iuphar.ligand:11783'],
#  ['AZD6482', 80, 'iuphar.ligand:8059'],
#  ['AZD6738', 60, 'ncit:C111993'],
#  ['AZD6765', 60, 'ncit:C77601'],
#  ['AZD7545', 80, 'iuphar.ligand:9362'],
#  ['AZD7594', 60, 'ncit:C171915'],
#  ['AZD7687', 80, 'iuphar.ligand:7827'],
#  ['AZD7762', 80, 'iuphar.ligand:7713'],
#  ['AZD7986', 60, 'ncit:C171778'],
#  ['AZD8055', 80, 'iuphar.ligand:7714'],
#  ['AZD8186', 80, 'iuphar.ligand:8527'],
#  ['AZD8330', 80, 'iuphar.ligand:8474'],
#  ['AZD8797', None, None],
#  ['AZD8835', 80, 'iuphar.ligand:8915'],
#  ['AZD8931', 60, 'ncit:C77887'],
#  ['AZD9056', 80, 'iuphar.ligand:7826'],
#  ['AZD9272', 80, 'iuphar.ligand:6439'],
#  ['AZD9496', 60, 'ncit:C122834'],
#  ['AZD9668', 60, 'ncit:C125714'],
#  ['azelaic-acid', None, None],
#  ['azelastine', 80, 'rxcui:18603'],
#  ['azeliragon', 80, 'ncit:C174675'],
#  ['azelnidipine', 80, 'ncit:C73023'],
#  ['azilsartan', 80, 'rxcui:1091642'],
#  ['azilsartan-medoxomil', None, None],
#  ['azimilide', 80, 'ncit:C79923'],
#  ['azithromycin', 80, 'rxcui:1299904'],
#  ['azlocillin', 80, 'rxcui:1266'],
#  ['AZM-475271', 80, 'chembl:CHEMBL3545150'],
#  ['azodicarbonamide', None, None],
#  ['azomycin-(2-nitroimidazole)', None, None],
#  ['azosemide', 80, 'rxcui:18651'],
#  ['aztreonam', 80, 'rxcui:1272'],
#  ['AZ191', 80, 'iuphar.ligand:9268'],
#  ['AZ20', 80, 'iuphar.ligand:8477'],
#  ['AZ3146', 80, 'iuphar.ligand:9400'],
#  ['AZ505', 80, 'iuphar.ligand:7021'],
#  ['AZ5104', 80, 'iuphar.ligand:11580'],
#  ['AZ7550', None, None],
#  ['AZ960', 80, 'iuphar.ligand:8476'],
#  ['A0001', None, None],
#  ['A12B4C3', None, None],
#  ['A205804', None, None],
#  ['A61603', 80, 'iuphar.ligand:480'],
#  ['A66', None, None],
#  ['A740003', 80, 'iuphar.ligand:4119'],
#  ['A77636', 80, 'iuphar.ligand:9637'],
#  ['A922500', None, None],
#  ['bacampicillin', 80, 'rxcui:18687'],
#  ['bacitracin', 80, 'rxcui:1291'],
#  ['bacitracin-zinc', None, None],
#  ['baclofen', 80, 'rxcui:1292'],
#  ['BADGE', 80, 'iuphar.ligand:2708'],
#  ['bafetinib', 80, 'ncit:C62516'],
#  ['bafilomycin-a1', None, None],
#  ['BAG-956', None, None],
#  ['baicalein', 80, 'rxcui:1592893'],
#  ['baicalin', 80, 'rxcui:1440261'],
#  ['bakuchiol', 80, 'rxcui:1368134'],
#  ['balaglitazone', 80, 'ncit:C78125'],
#  ['balapiravir', 80, 'ncit:C87439'],
#  ['balicatib', 80, 'ncit:C79521'],
#  ['balofloxacin', 80, 'ncit:C72631'],
#  ['baloxavir', 80, 'rxcui:2197842'],
#  ['baloxavir-marboxil', None, None],
#  ['balsalazide', 80, 'rxcui:18747'],
#  ['bamaquimast', 80, 'ncit:C72939'],
#  ['bambuterol', 80, 'rxcui:18751'],
#  ['BAM7', None, None],
#  ['BAN-ORL-24', None, None],
#  ['banoxantrone', 80, 'ncit:C79528'],
#  ['barasertib', 80, 'ncit:C62502'],
#  ['barasertib-HQPA', 80, 'iuphar.ligand:5663'],
#  ['bardoxolone', 80, 'ncit:C48382'],
#  ['bardoxolone-methyl', None, None],
#  ['baricitinib', 80, 'rxcui:2047232'],
#  ['barium-6-O-phosphonato-D-glucose', None, None],
#  ['barnidipine', 80, 'rxcui:39879'],
#  ['basic-fuchsin', None, None],
#  ['basimglurant', 80, 'ncit:C166619'],
#  ['basmisanil', 80, 'ncit:C167009'],
#  ['batefenterol', 80, 'ncit:C166503'],
#  ['batimastat', 80, 'ncit:C1529'],
#  ['bavisant', 80, 'ncit:C171762'],
#  ['BAX-channel-blocker', None, None],
#  ['BAY-K-8644-(+/-)', None, None],
#  ['BAY-K-8644-(s)-(-)', None, None],
#  ['BAY-W-9798', None, None],
#  ['BAY-11-7082', 60, 'iuphar.ligand:5934'],
#  ['BAY-11-7085', 80, 'chembl:CHEMBL270299'],
#  ['BAY-1251152', 60, 'iuphar.ligand:11686'],
#  ['BAY-1436032', 60, 'ncit:C131690'],
#  ['BAY-1895344', 60, 'ncit:C146807'],
#  ['BAY-2402234', 60, 'ncit:C153137'],
#  ['BAY-41-2272', None, None],
#  ['BAY-60-6583', 60, 'iuphar.ligand:3289'],
#  ['BAY-60-7550', 60, 'iuphar.ligand:5147'],
#  ['BAY-61-3606', 60, 'iuphar.ligand:9693'],
#  ['BAY-8002', 80, 'iuphar.ligand:10405'],
#  ['BAY-85-8050', 60, 'ncit:C157280'],
#  ['BAY-87-2243', None, None],
#  ['BAY1125976', 80, 'iuphar.ligand:10908'],
#  ['BAY1217389', None, None],
#  ['bazedoxifene', 80, 'rxcui:1441386'],
#  ['BAZ2-ICR', 80, 'iuphar.ligand:8571'],
#  ['BC-11', None, None],
#  ['BCI-540', None, None],
#  ['BCTC', 80, 'iuphar.ligand:2460'],
#  ['BCX-1470', None, None],
#  ['BD-1008', 60, 'chembl:CHEMBL20377'],
#  ['BD-1047', 80, 'iuphar.ligand:6680'],
#  ['BD-1063', 80, 'iuphar.ligand:12125'],
#  ['BE-2254', None, None],
#  ['BEBT-908', None, None],
#  ['beclabuvir', 80, 'ncit:C114983'],
#  ['beclamide', 80, 'rxcui:18846'],
#  ['beclomethasone', 80, 'rxcui:1347'],
#  ['beclomethasone-dipropionate', None, None],
#  ['bedaquiline', 80, 'rxcui:1364503'],
#  ['befuraline', 80, 'ncit:C72720'],
#  ['begacestat', 80, 'ncit:C76054'],
#  ['bekanamycin', 80, 'ncit:C65248'],
#  ['belinostat', 80, 'rxcui:1543543'],
#  ['belizatinib', 80, 'ncit:C169804'],
#  ['belotecan', 80, 'ncit:C73305'],
#  ['bemegride', 80, 'ncit:C76617'],
#  ['bemesetron', 80, 'ncit:C80766'],
#  ['bemotrizinol', 80, 'rxcui:1306115'],
#  ['bempedoic-acid', None, None],
#  ['benactyzine', 80, 'rxcui:1361'],
#  ['benaxibine', 80, 'ncit:C73231'],
#  ['benazepril', 80, 'rxcui:18867'],
#  ['bendamustine', 80, 'rxcui:134547'],
#  ['bendazac', 80, 'ncit:C80537'],
#  ['bendazol', 80, 'ncit:C74427'],
#  ['bendroflumethiazide', 80, 'rxcui:1369'],
#  ['benethamine', None, None],
#  ['benfluorex', 80, 'rxcui:18880'],
#  ['benfluralin', 80, 'chembl:CHEMBL1256668'],
#  ['benfotiamine', 80, 'rxcui:18891'],
#  ['benidipine', 80, 'ncit:C81680'],
#  ['benperidol', 80, 'rxcui:1373'],
#  ['benproperine', 80, 'rxcui:236749'],
#  ['benserazide', 80, 'rxcui:1374'],
#  ['bentiromide', 80, 'rxcui:18896'],
#  ['benurestat', 80, 'ncit:C81697'],
#  ['benzalkonium', 80, 'rxcui:1378'],
#  ['benzamil', 80, 'iuphar.ligand:4145'],
#  ['benzbromarone', 80, 'rxcui:1385'],
#  ['benzenemethanol,-2,5-dimethyl-[[(1-methylethyl)amino]methyl]', None, None],
#  ['benzethonium', 80, 'rxcui:1390'],
#  ['benznidazole', 80, 'rxcui:18994'],
#  ['benzo[d]thiazole-2(3H)-thione', None, None],
#  ['benzocaine', 80, 'rxcui:1399'],
#  ['benzoclidine', 80, 'ncit:C77243'],
#  ['benzofenac', None, None],
#  ['benzoic-acid', None, None],
#  ['benzoin', 80, 'ncit:C77026'],
#  ['benzonatate', 80, 'rxcui:18993'],
#  ['benzoquinonium-dibromide', None, None],
#  ['benzotript', 80, 'ncit:C76479'],
#  ['benzoxiquine', 80, 'rxcui:314521'],
#  ['benzoyl-peroxide', None, None],
#  ['benzoylpas', 80, 'ncit:C73820'],
#  ['benzthiazide', 80, 'rxcui:19008'],
#  ['benztropine-mesylate', None, None],
#  ['benzydamine', 80, 'rxcui:1425'],
#  ['benzyl-alcohol', None, None],
#  ['benzyl-benzoate', None, None],
#  ['benzyl-isothiocyanate', None, None],
#  ['benzyldimethylhexadecylammonium', None, None],
#  ['benzyldimethyloctylammonium', None, None],
#  ['benzylpenicillin', 80, 'rxcui:203133'],
#  ['bephenium-hydroxynaphthoate', None, None],
#  ['bepotastine', 80, 'rxcui:658552'],
#  ['bepridil', 80, 'rxcui:1436'],
#  ['berberine', 80, 'rxcui:1437'],
#  ['bergapten', 80, 'rxcui:15842'],
#  ['bergenin', 80, 'ncit:C79897'],
#  ['besifloxacin', 80, 'rxcui:819911'],
#  ['BET-BAY-002', None, None],
#  ['beta-amyloid-synthesis-inhibitor', None, None],
#  ['beta-carotene', 80, 'rxcui:19143'],
#  ['beta-CCB', None, None],
#  ['beta-elemene', 80, 'ncit:C103177'],
#  ['beta-funaltrexamine', 60, 'iuphar.ligand:1631'],
#  ['beta-glycerophosphoric-acid', None, None],
#  ['beta-hydroxy-beta-methylbutyrate', None, None],
#  ['beta-hydroxybutyrate', 60, 'chembl:CHEMBL1162496'],
#  ['beta-lapachone', 60, 'ncit:C28694'],
#  ['beta-naphthol', 60, 'ncit:C81517'],
#  ['betahistine', 80, 'rxcui:1511'],
#  ['betaine', 80, 'rxcui:1512'],
#  ['betamethasone', 80, 'rxcui:1514'],
#  ['betamethasone-acetate', None, None],
#  ['betamethasone-butyrate-propionate', None, None],
#  ['betamethasone-dipropionate', None, None],
#  ['betamethasone-phosphate', None, None],
#  ['betamethasone-valerate', None, None],
#  ['betamipron', 80, 'ncit:C72565'],
#  ['betaxolol', 80, 'rxcui:1520'],
#  ['betazole', 80, 'drugbank:DB00272'],
#  ['bethanechol', 80, 'rxcui:19257'],
#  ['BETP', 80, 'iuphar.ligand:7585'],
#  ['betrixaban', 80, 'rxcui:1927851'],
#  ['betulinic-acid', None, None],
#  ['bevantolol', 80, 'ncit:C79556'],
#  ['bevenopran', 80, 'ncit:C169810'],
#  ['bevirimat-dimeglumine', None, None],
#  ['bexagliflozin', 80, 'ncit:C169811'],
#  ['bexarotene', 80, 'rxcui:233272'],
#  ['bezafibrate', 80, 'rxcui:1525'],
#  ['BFH772', 80, 'drugbank:DB16035'],
#  ['BGP-15', 80, 'chembl:CHEMBL4747845'],
#  ['BGT226', 60, 'ncit:C74073'],
#  ['BHQ', 80, 'drugbank:DB04638'],
#  ['BI-D1870', 80, 'iuphar.ligand:8038'],
#  ['BI-224436', None, None],
#  ['BI-2536', 80, 'iuphar.ligand:5666'],
#  ['BI-409306', 60, 'chembl:CHEMBL4206492'],
#  ['BI-78D3', 60, 'chembl:CHEMBL508280'],
#  ['BI-847325', None, None],
#  ['BIA-10-2474', 60, 'iuphar.ligand:9001'],
#  ['biapenem', 80, 'ncit:C72620'],
#  ['BIBN4096', None, None],
#  ['BIBR-1532', None, None],
#  ['BIBU-1361', None, None],
#  ['BIBX-1382', 60, 'ncit:C80868'],
#  ['bicalutamide', 80, 'rxcui:83008'],
#  ['bicifadine', 80, 'ncit:C79930'],
#  ['bictegravir', 80, 'rxcui:1999660'],
#  ['bicuculline-(+)', None, None],
#  ['bicuculline-methochloride-(-)', None, None],
#  ['bicyclol', 80, 'drugbank:DB16014'],
#  ['bifemelane', 80, 'rxcui:47111'],
#  ['bifendate', 80, 'chembl:CHEMBL105184'],
#  ['bifonazole', 80, 'rxcui:19295'],
#  ['BIIB021', 80, 'drugbank:DB12359'],
#  ['bilastine', 80, 'ncit:C73045'],
#  ['bilobalide', 80, 'iuphar.ligand:2366'],
#  ['bimatoprost', 80, 'rxcui:283810'],
#  ['BIMU-8', 60, 'iuphar.ligand:234'],
#  ['BINA', 60, 'iuphar.ligand:3954'],
#  ['bindarit', 80, 'ncit:C96701'],
#  ['binimetinib', 80, 'rxcui:2049122'],
#  ['BIO-1211', 60, 'iuphar.ligand:6589'],
#  ['BIO-5192', None, None],
#  ['biotin', 80, 'rxcui:1588'],
#  ['bipenamol', 80, 'ncit:C79854'],
#  ['biperiden', 80, 'rxcui:1589'],
#  ['birinapant', 80, 'ncit:C88295'],
#  ['BIRT-377', 60, 'iuphar.ligand:9720'],
#  ['bis(maltolato)oxovanadium(IV)', 80, 'chembl:CHEMBL286447'],
#  ['bisacodyl', 80, 'rxcui:1596'],
#  ['bisantrene', 80, 'ncit:C1019'],
#  ['bisindolylmaleimide-IX', None, None],
#  ['bismuth(III)-trifluoromethanesulfonate', None, None],
#  ['bismuth-oxalate', None, None],
#  ['bismuth-subcitrate-potassium', None, None],
#  ['bismuth-subgallate', None, None],
#  ['bismuth-subsalicylate', None, None],
#  ['bisoctrizole', 80, 'rxcui:1310510'],
#  ['bisoprolol', 80, 'rxcui:19484'],
#  ['bisphenol-A', 60, 'drugbank:DB06973'],
#  ['bithionol', 80, 'ncit:C77030'],
#  ['bitopertin', 80, 'ncit:C174879'],
#  ['bitoscanate', 80, 'ncit:C72149'],
#  ['bivalirudin', 80, 'rxcui:60819'],
#  ['BIX-01294', 80, 'iuphar.ligand:7014'],
#  ['BIX-02188', 60, 'iuphar.ligand:8064'],
#  ['BIX-02189', 60, 'iuphar.ligand:9380'],
#  ['BL-5583', None, None],
#  ['blebbistatin-(+/-)', None, None],
#  ['blebbistatin-(-)', None, None],
#  ['bleomycetin', 60, 'ncit:C1279'],
#  ['bleomycin', 80, 'rxcui:1622'],
#  ['blonanserin', 80, 'ncit:C95920'],
#  ['BLU9931', 60, 'ncit:C162342'],
#  ['BLZ945', 80, 'chembl:CHEMBL4227505'],
#  ['BML-190', None, None],
#  ['BML-284', None, None],
#  ['BMS-CCR2-22', None, None],
#  ['BMS-182874', 80, 'chembl:CHEMBL267458'],
#  ['BMS-191011', 60, 'chembl:CHEMBL45349'],
#  ['BMS-191095', 80, 'chembl:CHEMBL11594'],
#  ['BMS-207940', 60, 'chembl:CHEMBL277447'],
#  ['BMS-214662', 80, 'ncit:C1856'],
#  ['BMS-265246', 80, 'iuphar.ligand:8051'],
#  ['BMS-299897', 60, 'chembl:CHEMBL247471'],
#  ['BMS-309403', 60, 'iuphar.ligand:6735'],
#  ['BMS-345541', 80, 'iuphar.ligand:5669'],
#  ['BMS-387032', 80, 'iuphar.ligand:5670'],
#  ['BMS-470539', None, None],
#  ['BMS-536924', 80, 'iuphar.ligand:9386'],
#  ['BMS-566419', None, None],
#  ['BMS-582949', 80, 'drugbank:DB12696'],
#  ['BMS-587101', 60, 'chembl:CHEMBL214529'],
#  ['BMS-599626', 80, 'drugbank:DB12318'],
#  ['BMS-626529', 60, 'chembl:CHEMBL3301620'],
#  ['BMS-626531', None, None],
#  ['BMS-649', None, None],
#  ['BMS-688521', 60, 'chembl:CHEMBL214529'],
#  ['BMS-690514', 80, 'drugbank:DB11665'],
#  ['BMS-707035', 80, 'chembl:CHEMBL486226'],
#  ['BMS-754807', 80, 'drugbank:DB15399'],
#  ['BMS-770767', 80, 'chembl:CHEMBL4802167'],
#  ['BMS-777607', 80, 'drugbank:DB12064'],
#  ['BMS-779788', 80, 'chembl:CHEMBL3545418'],
#  ['BMS-806', 60, 'chembl:CHEMBL337301'],
#  ['BMS-813160', 80, 'drugbank:DB16240'],
#  ['BMS-817378', 80, 'chembl:CHEMBL3545050'],
#  ['BMS-833923', 80, 'iuphar.ligand:8202'],
#  ['BMS-863233', 80, 'drugbank:DB12357'],
#  ['BMS-906024', 80, 'ncit:C116872'],
#  ['BMS-911543', 80, 'drugbank:DB12591'],
#  ['BMS-935177', None, None],
#  ['BMS-983970', None, None],
#  ['BMS-986020', 80, 'drugbank:DB14948'],
#  ['BMS-986142', 80, 'drugbank:DB15291'],
#  ['BMS-986158', 80, 'drugbank:DB15435'],
#  ['BMS-986195', 60, 'ncit:C167033'],
#  ['BMS-986205', 60, 'ncit:C141135'],
#  ['BMY-14802', 80, 'iuphar.ligand:8'],
#  ['BMY-45778', 60, 'iuphar.ligand:1963'],
#  ['BMY-7378', 80, 'iuphar.ligand:9'],
#  ['BNC105', 80, 'drugbank:DB06313'],
#  ['BNTX', 80, 'iuphar.ligand:1634'],
#  ['boceprevir', 80, 'rxcui:1102129'],
#  ['bonaphthone', None, None],
#  ['bopindolol', 80, 'rxcui:19605'],
#  ['bornyl-acetate', None, None],
#  ['boronophenylalanine', None, None],
#  ['bortezomib', 80, 'rxcui:358258'],
#  ['BOS-172722', None, None],
#  ['bosentan', 80, 'rxcui:1468845'],
#  ['bosutinib', 80, 'rxcui:1307619'],
#  ['BP-554', None, None],
#  ['BP-897', 80, 'iuphar.ligand:7625'],
#  ['BQ-123', 80, 'drugbank:DB12054'],
#  ['BQ-788', 60, 'iuphar.ligand:1010'],
#  ['BQU57', None, None],
#  ['BRD4770', 80, 'iuphar.ligand:7016'],
#  ['BRD7389', None, None],
#  ['BRD9876', None, None],
#  ['brefeldin-A', None, None],
#  ['bremelanotide', 80, 'rxcui:2176312'],
#  ['brequinar', 80, 'ncit:C1560'],
#  ['bretazenil', 80, 'ncit:C72111'],
#  ['bretylium', 80, 'rxcui:19685'],
#  ['brexpiprazole', 80, 'rxcui:1658314'],
#  ['briciclib', 80, 'ncit:C141431'],
#  ['brigatinib', 80, 'rxcui:1921217'],
#  ['brilliant-green', None, None],
#  ['brimonidine', 80, 'rxcui:134615'],
#  ['brincidofovir', 80, 'rxcui:2599518'],
#  ['brinzolamide', 80, 'rxcui:194881'],
#  ['brivanib', 80, 'ncit:C67040'],
#  ['brivanib-alaninate', None, None],
#  ['brivudine', 80, 'rxcui:59161'],
#  ['BRL-15572', 80, 'iuphar.ligand:10'],
#  ['BRL-26314', None, None],
#  ['BRL-37344', 60, 'iuphar.ligand:567'],
#  ['BRL-44408', 60, 'iuphar.ligand:525'],
#  ['BRL-50481', 60, 'iuphar.ligand:5154'],
#  ['BRL-52537', 60, 'chembl:CHEMBL1256835'],
#  ['BRL-54443', 80, 'iuphar.ligand:3927'],
#  ['brolitene', None, None],
#  ['bromantan', None, None],
#  ['bromebric-acid', None, None],
#  ['bromfenac', 80, 'rxcui:19737'],
#  ['bromhexine', 80, 'rxcui:1753'],
#  ['bromindione', 80, 'ncit:C174809'],
#  ['bromisoval', 80, 'ncit:C76935'],
#  ['bromocriptine', 80, 'rxcui:1760'],
#  ['bromopride', 80, 'rxcui:19768'],
#  ['bromosporine', 80, 'iuphar.ligand:8234'],
#  ['bromperidol', 80, 'rxcui:19777'],
#  ['brompheniramine', 80, 'rxcui:1767'],
#  ['bronopol', 80, 'rxcui:1114345'],
#  ['bropirimine', 80, 'ncit:C1024'],
#  ['broxaldine', 80, 'ncit:C72598'],
#  ['broxaterol', 80, 'ncit:C74195'],
#  ['broxuridine', 80, 'ncit:C318'],
#  ['broxyquinoline', 80, 'ncit:C73253'],
#  ['bruceantin', 80, 'ncit:C1025'],
#  ['brucine', 80, 'rxcui:2181419'],
#  ['BS-181', 80, 'iuphar.ligand:9405'],
#  ['BT-11', 80, 'iuphar.ligand:10363'],
#  ['BTB06584', None, None],
#  ['BTB1', None, None],
#  ['BTK-IN-1', None, None],
#  ['BTS', 60, 'rxcui:35161'],
#  ['BTS-54505', None, None],
#  ['BTS-71321', None, None],
#  ...]

# %%
# Check that lengths agree
len(results_list) == len(df)
# Out:
# True

# %%
# Extract scores and concept IDs
all_scores = []
all_ids = []

for entry in tqdm(results_list):
    all_scores.append(entry[1]) # match score
    all_ids.append(entry[2]) # concept id
# Out:
# 100%|██████████| 6798/6798 [00:00<00:00, 1310093.67it/s]

# %%
# Add to dataframe
df['match_score'] = all_scores
df['concept_id'] = all_ids

# %% [markdown]
# #### Quantify Normalization

# %%
df
# Out:
#                         pert_iname clinical_phase  \
# 0              (R)-(-)-apomorphine       Launched
# 1                 (R)-(-)-rolipram        Phase 1
# 2                     (R)-baclofen        Phase 3
# 3                 (S)-(+)-rolipram        Phase 1
# 4     [sar9,met(o2)11]-substance-p    Preclinical
# ...                            ...            ...
# 6793                      8-M-PDOT    Preclinical
# 6794                    80841-78-7    Preclinical
# 6795               9-aminoacridine    Preclinical
# 6796           9-aminocamptothecin        Phase 2
# 6797   9-anthracenecarboxylic-acid    Preclinical
#
#                                   moa  \
# 0           dopamine receptor agonist
# 1         phosphodiesterase inhibitor
# 2     benzodiazepine receptor agonist
# 3         phosphodiesterase inhibitor
# 4               tachykinin antagonist
# ...                               ...
# 6793       melatonin receptor agonist
# 6794                              NaN
# 6795                              NaN
# 6796          topoisomerase inhibitor
# 6797                              NaN
#
#                                                  target          disease_area  \
# 0     ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...  neurology/psychiatry
# 1                         PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                   NaN
# 2                                         GABBR1|GABBR2                   NaN
# 3                                           PDE4B|PDE4D                   NaN
# 4                                                 TACR1                   NaN
# ...                                                 ...                   ...
# 6793                                      MTNR1A|MTNR1B                   NaN
# 6794                                                NaN                   NaN
# 6795                                                NaN                   NaN
# 6796                                               TOP1                   NaN
# 6797                                         ANO1|CLCN1                   NaN
#
#                indication  match_score        concept_id
# 0     Parkinson's Disease          NaN              None
# 1                     NaN         60.0       ncit:C72842
# 2                     NaN         60.0        rxcui:1292
# 3                     NaN          NaN              None
# 4                     NaN          NaN              None
# ...                   ...          ...               ...
# 6793                  NaN          NaN              None
# 6794                  NaN          NaN              None
# 6795                  NaN         60.0         rxcui:645
# 6796                  NaN         80.0  drugbank:DB12515
# 6797                  NaN          NaN              None
#
# [6798 rows x 8 columns]

# %%
df['normalization'] = df['concept_id'].apply(is_normalized)
df
# Out:
#                         pert_iname clinical_phase  \
# 0              (R)-(-)-apomorphine       Launched
# 1                 (R)-(-)-rolipram        Phase 1
# 2                     (R)-baclofen        Phase 3
# 3                 (S)-(+)-rolipram        Phase 1
# 4     [sar9,met(o2)11]-substance-p    Preclinical
# ...                            ...            ...
# 6793                      8-M-PDOT    Preclinical
# 6794                    80841-78-7    Preclinical
# 6795               9-aminoacridine    Preclinical
# 6796           9-aminocamptothecin        Phase 2
# 6797   9-anthracenecarboxylic-acid    Preclinical
#
#                                   moa  \
# 0           dopamine receptor agonist
# 1         phosphodiesterase inhibitor
# 2     benzodiazepine receptor agonist
# 3         phosphodiesterase inhibitor
# 4               tachykinin antagonist
# ...                               ...
# 6793       melatonin receptor agonist
# 6794                              NaN
# 6795                              NaN
# 6796          topoisomerase inhibitor
# 6797                              NaN
#
#                                                  target          disease_area  \
# 0     ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...  neurology/psychiatry
# 1                         PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                   NaN
# 2                                         GABBR1|GABBR2                   NaN
# 3                                           PDE4B|PDE4D                   NaN
# 4                                                 TACR1                   NaN
# ...                                                 ...                   ...
# 6793                                      MTNR1A|MTNR1B                   NaN
# 6794                                                NaN                   NaN
# 6795                                                NaN                   NaN
# 6796                                               TOP1                   NaN
# 6797                                         ANO1|CLCN1                   NaN
#
#                indication  match_score        concept_id normalization
# 0     Parkinson's Disease          NaN              None       Failure
# 1                     NaN         60.0       ncit:C72842       Success
# 2                     NaN         60.0        rxcui:1292       Success
# 3                     NaN          NaN              None       Failure
# 4                     NaN          NaN              None       Failure
# ...                   ...          ...               ...           ...
# 6793                  NaN          NaN              None       Failure
# 6794                  NaN          NaN              None       Failure
# 6795                  NaN         60.0         rxcui:645       Success
# 6796                  NaN         80.0  drugbank:DB12515       Success
# 6797                  NaN          NaN              None       Failure
#
# [6798 rows x 9 columns]

# %%
df['normalization'].value_counts()
# Out:
# Success    4966
# Failure    1832
# Name: normalization, dtype: int64

# %%
print('Success: ' + str(4966/(4966+1832)))
print('Failure: ' + str(1832/(4966+1832)))
# Out:
# Success: 0.7305089732274198
# Failure: 0.2694910267725802

# %% [markdown]
# #### Disease Inspection

# %%
# If an entry has a disease_area it also has an indication
diseases = df[df['disease_area'].isnull()==False]

# %%
diseases
# Out:
#                           pert_iname clinical_phase  \
# 0                (R)-(-)-apomorphine       Launched
# 32                          abacavir       Launched
# 34                         abamectin       Launched
# 39                       abemaciclib       Launched
# 40                       abiraterone       Launched
# ...                              ...            ...
# 6697  3-(4-methylbenzylidene)camphor       Launched
# 6725            4-aminohippuric-acid       Launched
# 6755           5-aminolevulinic-acid       Launched
# 6760                  5-fluorouracil       Launched
# 6766             5-hydroxytryptophan       Launched
#
#                                              moa  \
# 0                      dopamine receptor agonist
# 32    nucleoside reverse transcriptase inhibitor
# 34               benzodiazepine receptor agonist
# 39                                 CDK inhibitor
# 40               androgen biosynthesis inhibitor
# ...                                          ...
# 6697                         endocrine disruptor
# 6725                                         NaN
# 6755                             oxidizing agent
# 6760              thymidylate synthase inhibitor
# 6766                            neurotransmitter
#
#                                                  target          disease_area  \
# 0     ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...  neurology/psychiatry
# 32                                                  NaN    infectious disease
# 34                                        GABBR1|GABBR2    infectious disease
# 39                                            CDK4|CDK6              oncology
# 40                                      CYP11B1|CYP17A1              oncology
# ...                                                 ...                   ...
# 6697                                                NaN           dermatology
# 6725                                            SLC22A6            nephrology
# 6755                                               ALAD  oncology|dermatology
# 6760                                          DPYD|TYMS              oncology
# 6766                                    SLC36A1|SLC36A2  neurology/psychiatry
#
#                                              indication  match_score  \
# 0                                   Parkinson's Disease          NaN
# 32                 human immunodeficiency virus (HIV-1)         80.0
# 34                           gastrointestinal parasites         80.0
# 39                                        breast cancer         80.0
# 40                                      prostate cancer         80.0
# ...                                                 ...          ...
# 6697                                   sunscreen lotion         60.0
# 6725                             renal diagnostic agent          NaN
# 6755                      glioma|actinic keratosis (AK)          NaN
# 6760  colorectal cancer|breast cancer|pancreatic can...         80.0
# 6766                                           insomnia         80.0
#
#          concept_id normalization
# 0              None       Failure
# 32     rxcui:190521       Success
# 34      ncit:C95196       Success
# 39    rxcui:1946825       Success
# 40    rxcui:1100071       Success
# ...             ...           ...
# 6697  rxcui:1311507       Success
# 6725           None       Failure
# 6755           None       Failure
# 6760     rxcui:4492       Success
# 6766       rxcui:94       Success
#
# [2222 rows x 9 columns]

# %%
diseases['indication'].value_counts()
# Out:
# hypertension                                                                                                                       70
# diabetes mellitus                                                                                                                  31
# schizophrenia                                                                                                                      29
# pain relief                                                                                                                        29
# gram-negative bacterial infections                                                                                                 28
#                                                                                                                                    ..
# non-small cell lung cancer (NSCLC)|pancreatic cancer                                                                                1
# intra-abdominal infections|skin infections|pneumonia|urinary tract infections|gynecologic infections|postpartum endomyometritis     1
# depression|generalized anxiety disorder (GAD)                                                                                       1
# ventricular tachycardia (VT)|hypertension                                                                                           1
# colorectal cancer|breast cancer|pancreatic cancer|gastric adenocarcinoma                                                            1
# Name: indication, Length: 1009, dtype: int64

# %%
diseases['disease_area'].value_counts()
# Out:
# infectious disease                                             424
# neurology/psychiatry                                           346
# cardiology                                                     205
# gastroenterology                                               124
# endocrinology                                                  122
#                                                               ...
# oncology|neurology/psychiatry|genetics|urology                   1
# neurology/psychiatry|otolaryngology|endocrinology|pulmonary      1
# ophthalmology|gastroenterology                                   1
# neurology/psychiatry|endocrinology|otolaryngology                1
# oncology|dermatology                                             1
# Name: disease_area, Length: 216, dtype: int64

# %% [markdown]
# ### ReDO Trials
# Maybe this source? This does not have gene interactions necessarily, as far as I can tell. Perhaps within Outcome Measures? But it does have notions of diseases, phenotypes, clinical status, recruiting, drugbank associations

# %%
df2
# Out:
#            NCT Number                                              Title  \
# 0         NCT03047837  A Randomized, 2x2 Factorial Design Biomarker P...
# 1         NCT02969681  Vitamin C Intravenously With Chemotherapy in A...
# 2         NCT02497638      LIpitor and biGuanide to Androgen Delay Trial
# 3         NCT03275376  Statin Combination Therapy in Patients Receivi...
# 4         NCT03980249  Anti-Cancer Effects of Carvedilol With Standar...
# ..                ...                                                ...
# 902  ChiCTR2200061789  Fasudil hydrochloride in the treatment of gene...
# 903  ChiCTR2200066615  The effect of intraoperative intravenous lidoc...
# 904  ChiCTR2200065595  Exploratory Clinical Study on Mifepristone for...
# 905  ChiCTR2300068631  Oral aminophylline combined with sunitinib mal...
# 906  ChiCTR2300068563  lidocaine Effects on neutrophil extracellular ...
#
#       Acronym              Status  \
# 0      ASAMET          Recruiting
# 1    Vitality          Recruiting
# 2      LIGAND  Not yet recruiting
# 3         NaN          Recruiting
# 4         NaN  Not yet recruiting
# ..        ...                 ...
# 902       NaN             Pending
# 903       NaN             Pending
# 904       NaN             Pending
# 905       NaN          Recruiting
# 906       NaN             Pending
#
#                                             Conditions  \
# 0                  Tertiary Prevention in Colon Cancer
# 1                                 Colorectal Neoplasms
# 2                                      Prostate Cancer
# 3                     Overall Survival|Tumor Responses
# 4                 Glioblastoma|Glioblastoma Multiforme
# ..                                                 ...
# 902                                       Ovary cancer
# 903                                        Lung cancer
# 904                             Recurrent Glioblastoma
# 905  locally advanced unresectable renal clear cell...
# 906                                      breast cancer
#
#                                          Interventions  \
# 0    Drug: Aspirin (ASA) + Metformin (MET); Drug: A...
# 1              Drug: ascorbic acid; Drug: Chemotherapy
# 2    Drug: Metformin; Drug: Atorvastatin; Drug: Pla...
# 3    Drug: Atorvastatin 10mg; Drug: Placebo Oral Ta...
# 4                                     Drug: Carvedilol
# ..                                                 ...
# 902  first group:Fasudil Hydrochloride Injection;se...
# 903  Lidocaine group:Intraoperative intravenous lid...
# 904    treatment group:Administration of Mifepristone;
# 905  Test group:Aminophylline combined with sunitin...
# 906  Sevoflurane anesthesia experimental group:lido...
#
#                                       Outcome Measures  \
# 0    NF B; pS6K, p53, beta-catenin, PI3K; IL-6, CRP...
# 1    Progression Free Survival; Overall Survival; R...
# 2    Time to disease progression (defined as PSA ri...
# 3    Overall survival; Best tumor response; Progres...
# 4    Survival curve of overall survival; Survival c...
# ..                                                 ...
# 902  Number of treatment courses received;Overall s...
# 903            Overall survival;Disease free survival;
# 904  complete blood count;liver function test;kidne...
# 905                         Progression-free survival;
# 906                         MPO;H3Cit;NE;MMP-9;VEGF-A;
#
#                                               Sponsors  Gender  \
# 0                   Ente Ospedaliero Ospedali Galliera     All
# 1                               Sun Yat-sen University     All
# 2                   University Health Network, Toronto    Male
# 3                   Taichung Veterans General Hospital     All
# 4    West Virginia University; NovoCure Ltd.; West ...     All
# ..                                                 ...     ...
# 902        Tianjin Medical University General Hospital  Female
# 903               Zhongshan Hospital, Fudan University     All
# 904                 Huashan Hospital, Fudan University     All
# 905  Shanghai Sixth People's Hospital Affiliated to...     All
# 906     General Hospital of Ningxia Medical University  Female
#
#                                              Age  ... Multi-Arm Pediatric  \
# 0    18 Years to 80 Years   (Adult, Older Adult)  ...         N         N
# 1    18 Years to 75 Years   (Adult, Older Adult)  ...         N         N
# 2    18 Years to 80 Years   (Adult, Older Adult)  ...         N         N
# 3      40 Years and older   (Adult, Older Adult)  ...         N         N
# 4      18 Years and older   (Adult, Older Adult)  ...         N         N
# ..                                           ...  ...       ...       ...
# 902                                            -  ...         N         N
# 903                                            -  ...         N         N
# 904                                         18 -  ...         N         N
# 905                                      18 - 70  ...         N         N
# 906                                      18 - 70  ...         N         N
#
#         Country_PI    Cancer_Group                  Cancer_Type  \
# 0            Italy              GI  Colon Cancer; Rectal Cancer
# 1            China              GI                 Colon Cancer
# 2           Canada      Urological              Prostate Cancer
# 3           Taiwan              GI                 Liver Cancer
# 4    United States             CNS                 Glioblastoma
# ..             ...             ...                          ...
# 902          China  Gynaecological    Ovarian Epithelial Cancer
# 903          China            Lung             Any lung cancers
# 904          China             CNS                 Glioblastoma
# 905          China      Urological         Renal Cell Carcinoma
# 906          China          Breast            Any Breast Cancer
#
#                             Drug_INN       Primary-EP                  Phase  \
# 0    Acetylsalicylic Acid; Metformin        Biomarker                Phase 2
# 1                      Ascorbic acid              PFS                Phase 3
# 2            Atorvastatin; Metformin              PFS                Phase 2
# 3                       Atorvastatin               OS                Phase 2
# 4                         Carvedilol               OS                Phase 1
# ..                               ...              ...                    ...
# 902                          Fasudil          PFS; OS  Not available/Missing
# 903                        Lidocaine  OS; DFS/RFS/EFS  Not available/Missing
# 904                     Mifepristone        Biomarker  Not available/Missing
# 905                    Aminophylline              PFS  Not available/Missing
# 906                        Lidocaine        Biomarker  Not available/Missing
#
#                   DrugBank Removed
# 0         DB00210; DB06800       N
# 1                  DB00335       N
# 2         DB01117; DB06800       N
# 3                  DB01117       N
# 4                  DB00567       N
# ..                     ...     ...
# 902                DB00800       N
# 903  Not found in DrugBank       N
# 904                DB00370       N
# 905                DB01118       N
# 906  Not found in DrugBank       N
#
# [907 rows x 40 columns]

# %%
df2.keys()
# Out:
# Index(['NCT Number', 'Title', 'Acronym', 'Status', 'Conditions',
#        'Interventions', 'Outcome Measures', 'Sponsors', 'Gender', 'Age',
#        'Enrollment', 'Funders', 'Study Type', 'Study Designs', 'Other IDs',
#        'Start Date', 'Primary Completion Date', 'Completion Date',
#        'Last Verified', 'First Submitted', 'First Posted',
#        'Results First Submitted', 'Results First Posted',
#        'Last Update Submitted', 'Last Update Posted', 'URL', 'Setting',
#        'Stage', 'Sponsor_Type', 'Controlled', 'Multi-Arm', 'Pediatric',
#        'Country_PI', 'Cancer_Group', 'Cancer_Type', 'Drug_INN', 'Primary-EP',
#        'Phase', 'DrugBank', 'Removed'],
#       dtype='object')

# %%
df2['Drug_INN'].value_counts()
# Out:
# Metformin                                                                                                                                                                                             113
# Celecoxib                                                                                                                                                                                              43
# Hydroxychloroquine                                                                                                                                                                                     41
# Acetylsalicylic Acid                                                                                                                                                                                   32
# Ascorbic acid                                                                                                                                                                                          30
#                                                                                                                                                                                                      ...
# Pertussis vaccine                                                                                                                                                                                       1
# Ketoconazole; Posaconazole                                                                                                                                                                              1
# Albendazole; Chloroquine; Clarithromycin; Clotrimazole; Dapsone; Doxycycline; Itraconazole; Ivermectin; Levamisole; Mebendazole; Metronidazole; Miconazole; Miltefosine; Nitazoxanide; Terbinafine      1
# Memantine                                                                                                                                                                                               1
# Aminophylline                                                                                                                                                                                           1
# Name: Drug_INN, Length: 209, dtype: int64

# %%
df2['Outcome Measures'].value_counts()
# Out:
# Progression Free Survival;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  3
# objective response rate                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     2
# Progression free survival                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2
# Overall survival; The presence of disease progression; Postoperative complications; Karnofsky performance status score; Length of hospital stays                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            2
# Response rate; Pathomorphological response; Adverse events incidence                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# Ki67 evaluation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Comparison of the histological traits of invasive tumour front of the surgical tumour resection specimen between the intervention group and the placebo group: 1. Fascin1 expression in tumour tissue: It will be analysed by immunohistochemistry and the application of Immunoscore. 2. Histological manifestations of the epithelial-mesenchymal transition (EMT): Tumour budding, cytoplasmic pseudo-fragments, infiltrating growth pattern and poorly differentiated nests. It will be evaluated by histological analysis. 3. Invasive histological manifestations: discontinuous extramural extension, lymphatic, venous and perineural infiltration. It will be evaluated by histological analysis. 4. Histological manifestation of the immune response: Peritumoral and intratumour lymphocyte infiltration. It will be evaluated by histological analysis. 5. EMT molecular manifestations: FSCN1, SNAIL and SLUG gene expression. It will be evaluated by NGS analysis of the primary tumour.    1
# 1) Progression-free survival (PFS); 2) Tg levels have been trending over time.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Progression-free survival (PFS)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# MPO;H3Cit;NE;MMP-9;VEGF-A;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Name: Outcome Measures, Length: 897, dtype: int64

# %% [markdown]
# ### repoDB

# %%
df3
# Out:
#           drug_name  drug_id  \
# 0         Lepirudin  DB00001
# 1         Cetuximab  DB00002
# 2         Cetuximab  DB00002
# 3         Cetuximab  DB00002
# 4         Cetuximab  DB00002
# ...             ...      ...
# 10557  Temozolomide  DB00853
# 10558     Dasatinib  DB01254
# 10559   Dacarbazine  DB00851
# 10560  Temozolomide  DB00853
# 10561     Dasatinib  DB01254
#
#                                                ind_name    ind_id  \
# 0      Heparin-induced thrombocytopenia with thrombosis  C0272275
# 1                      Squamous cell carcinoma of mouth  C0585362
# 2                       Squamous cell carcinoma of nose  C3163899
# 3                    Squamous cell carcinoma of pharynx  C1319317
# 4                     Laryngeal Squamous Cell Carcinoma  C0280324
# ...                                                 ...       ...
# 10557                                      CNS disorder  C0007682
# 10558                                      CNS disorder  C0007682
# 10559                                    Brain Diseases  C0006111
# 10560                                    Brain Diseases  C0006111
# 10561                                    Brain Diseases  C0006111
#
#                NCT     status    phase  \
# 0              NaN   Approved      NaN
# 1              NaN   Approved      NaN
# 2              NaN   Approved      NaN
# 3              NaN   Approved      NaN
# 4              NaN   Approved      NaN
# ...            ...        ...      ...
# 10557  NCT02661113  Withdrawn  Phase 2
# 10558  NCT02661113  Withdrawn  Phase 2
# 10559  NCT02661113  Withdrawn  Phase 2
# 10560  NCT02661113  Withdrawn  Phase 2
# 10561  NCT02661113  Withdrawn  Phase 2
#
#                                           DetailedStatus
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10557  Sponsor withdrew support; Study did not progre...
# 10558  Sponsor withdrew support; Study did not progre...
# 10559  Sponsor withdrew support; Study did not progre...
# 10560  Sponsor withdrew support; Study did not progre...
# 10561  Sponsor withdrew support; Study did not progre...
#
# [10562 rows x 8 columns]

# %%
df3['drug_name'].nunique()
# Out:
# 1572

# %% [markdown]
# This data was built from DrugCentral 2016 release and AACT 2016 (association of clinical trials database) which I can't even find. This data feels fairly potentially out of date....I think more up-to-date relevant sources would probably be a better fit. COuld this be good for historic capture or perhaps looking for things which we don't have coverage?
#
# https://www.nature.com/articles/sdata201729

# %% [markdown]
# repoDB spans 1,571 drugs and 2,051 UMLS disease concepts, accounting for 6,677 approved and 4,123 failed drug-indication pairs (see Table 2 and Fig. 1b for trial status breakdown).
#
# Seems potentially useful for pulling in indication pairs? This potentially might have some already overlapped data though? Also still given that it's indication of use data, this is approach almost 10 years of age. Would be better to have a cool way to pull this in automatically, say from the FDA.
